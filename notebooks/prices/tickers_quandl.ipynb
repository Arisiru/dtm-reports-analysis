# %% [markdown]
# # Ticker price: get historical prices from Quandl

# %% [markdown]
# ## The project initialization

# %%
import numpy as np
import quandl
import csv
import datetime as dt
import time
import os

# %% [markdown]
# ## Target dates
# Please setup the time frame for your analysis. The start and the end dates should be formated "yyyy-mm-dd".
#
# __the start date will be included in resuld but end date not.__

# %%
start_date = dt.datetime.strptime('2006-01-01', '%Y-%m-%d')
end_date = dt.datetime.strptime('2016-01-02', '%Y-%m-%d')

data_raw_path = os.path.join('..', 'data_raw')
data_processing_path = os.path.join('..', 'data_processing')

# %% [markdown]
# ## Quandl api key
# Quandl library requare you to include your api key to every request.
# Please set variablee Q_API_KEY with your current api key.
# For more information about quandl API please follow [Quandl API Documentation](https://docs.quandl.com/)

# %%
#todo remove this key or move it in separate file
QUANDLE_API_KEY = "6xuzY1esVsm6ghCi7ocz"

# %% [markdown]
# # Download close prices
# _The following chapter will downlad historical prices for a given list of tickers_

# %%
quandl.ApiConfig.api_key = QUANDLE_API_KEY

# %% [markdown]
# ## Load list of target tickers

# %%
tickers_file = os.path.join(data_processing_path, 'tickers', 'tickers.csv')

# %% [markdown]
# _Please make sure what tickers.txt exist, in the output of the next cell you should see the first 5 tickers codes in your tickers.txt, if not you need to go to the "ticker processing" notebook_

# %%
# !head -n 5 $tickers_file
# Out:
# ticker,ticker_index,ticker_yahoo,ticker_quandl
# AAL,AAL_FTSE,AAL.L,LSE/AAL
# ABF,ABF_FTSE,ABF.L,LSE/ABF
# ACA,ACA_CAC,ACA.PA,EURONEXT/ACA
# AC,AC_CAC,AC.PA,EURONEXT/AC

# %% [markdown]
# ## Download close prices

# %% [markdown]
# Close prices for every day in given time frame will be saved in directory 'closePrices' which will be cleaned up at the shutdown chapter of this notebook

# %%
start_date_string = start_date.strftime('%Y-%m-%d')
end_date_string = end_date.strftime('%Y-%m-%d')
price_path = os.path.join(data_processing_path, 'prices', 'quandl')

if not os.path.isdir(price_path):
    os.mkdir(price_path)

with open(tickers_file, 'r') as f_r:
    reader = csv.DictReader(f_r)

    calls = 0
    for row in reader:
        data_result = None
        try:
            data_result = quandl.get(row['ticker_quandl'], start_date=start_date_string, end_date=end_date_string)
        except Exception as ex:
            print("Error for ticker %s: %s" % (row['ticker_index'], ex))

        if data_result is not None:
            calls += 1;
            file_result = os.path.join(price_path, "%s.csv" % row['ticker_index'])
            data_result.to_csv(file_result, encoding='utf-8')
        
        if calls > 299:
            calls = 0;
            time.sleep(10);
# Out:
# Error for ticker VZ_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker CAT_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker PFE_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker MMM_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker WMT_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker CVX_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker INTC_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker GS_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker HD_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker MFST_NASDAQ: (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.
# Error for ticker MRK_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker JNJ_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker MCD_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker T_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker IBM_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker PG_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker XOM_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker BA_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker GE_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker DD_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker UNH_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker DIS_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker CSCO_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker KO_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker AXP_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker TVE_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker NKE_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker V_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker UTX_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker JPM_NASDAQ: (Status 403) (Quandl Error QEPx04) You do not have permission to view this dataset. Please subscribe to this database to get access.
# Error for ticker DN_CAC: (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.
# Error for ticker XTA_FTSE: (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.
# Error for ticker ENRC_FTSE: (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.
# Error for ticker RSDA_FTSE: (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.
# Error for ticker BTI_FTSE: (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.
# Error for ticker SHPG_FTSE: (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.
# Error for ticker HSBC_FTSE: (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.
# Error for ticker BT_FTSE: (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.
# Error for ticker BG_FTSE: (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.
# Error for ticker PSO_FTSE: (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.
# Error for ticker TT_FTSE: (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.

# %% [markdown]
# ### Test
# _use it to test presense of a ticker code in Quanl_

# %%
start_date_string = start_date.strftime('%Y-%m-%d')
end_date_string = end_date.strftime('%Y-%m-%d')

#returns 403 for free account
#quandl.get('XNYS/AXP', start_date=start_date_string, end_date=end_date_string)

#returns 404
#quandl.get('FSE/ALL_XP', start_date=start_date_string, end_date=end_date_string) 

#expected return
quandl.get('LSE/GKN', start_date=start_date_string, end_date=end_date_string)
# Out:
#                Price    High     Low      Volume  Last Close  Change  Var%
# Date
# 2006-03-16  221.0327     NaN     NaN   8684378.0    221.0327     NaN   NaN
# 2006-03-17  221.7076     NaN     NaN   9019770.0    221.7076     NaN   NaN
# 2006-03-20  225.0822     NaN     NaN   6968807.0    225.0822     NaN   NaN
# 2006-03-21  223.5636     NaN     NaN   6718781.0    223.5636     NaN   NaN
# 2006-03-22  224.7447     NaN     NaN   6964714.0    224.7447     NaN   NaN
# 2006-03-23  221.3702     NaN     NaN   6212029.0    221.3702     NaN   NaN
# 2006-03-24  222.5513     NaN     NaN   9912789.0    222.5513     NaN   NaN
# 2006-03-27  226.6007     NaN     NaN  10617177.0    226.6007     NaN   NaN
# 2006-03-28  228.4567     NaN     NaN  17952621.0    228.4567     NaN   NaN
# 2006-03-29  227.4444     NaN     NaN   6684658.0    227.4444     NaN   NaN
# 2006-03-30  227.1069     NaN     NaN   4979214.0    227.1069     NaN   NaN
# 2006-03-31  224.4073     NaN     NaN  10931193.0    224.4073     NaN   NaN
# 2006-04-03  225.9258     NaN     NaN   9394611.0    225.9258     NaN   NaN
# 2006-04-04  225.5884     NaN     NaN   9235170.0    225.5884     NaN   NaN
# 2006-04-05  227.4444     NaN     NaN   4662238.0    227.4444     NaN   NaN
# 2006-04-06  226.7695     NaN     NaN   6696279.0    226.7695     NaN   NaN
# 2006-04-07  224.0698     NaN     NaN   3706082.0    224.0698     NaN   NaN
# 2006-04-10  223.3949     NaN     NaN   4571068.0    223.3949     NaN   NaN
# 2006-04-11  223.3949     NaN     NaN   5463892.0    223.3949     NaN   NaN
# 2006-04-12  217.4895     NaN     NaN  13925069.0    217.4895     NaN   NaN
# 2006-04-13  217.1520     NaN     NaN   3932618.0    217.1520     NaN   NaN
